# %%
#Exercicis amb Dataframes
#- Exercici 1

    #Descarrega el data set Airlines Delay: Airline on-time statistics and delay causes i carrega’l a un Pandas Dataframe. 
    #->Airlines Delay: Airline on-time statistics and delay causes


import pandas as pd

df = pd.read_csv("DelayedFlights.csv", parse_dates=True)


    #Important: Redueix la dimensió del dataset de manera aleatòria per tal d'obtenir un dataset de només 200.000 registres. 
    #Tots els exercicis s'han de fer amb aquest dataset reduït.

df2 = df.sample(n=200000)   
    
    #Explora les dades que conté, explica breument quines variables hi ha 
print("Les dades estan organitzades en 29 columnes, relatives als vols d'aeronaus. La primera columna(Unnamed:0) és un número correlatiu (al que li falten registres). La resta de columnes correspnoen a dades dels vols (dia del vol, hora de partida i d'arribada, lloc de sortida i destí, temps de retard, etc).\n\n")


df.info()  # --> el que més informació em proporciona (llistat amb el nom de les columnes i tipus de dades que contenen)    
print(df2.head(20))

    #i queda’t únicament amb les columnes que consideris rellevants. Justifica la teva elecció.
    #--> Decideixo eliminar les columnes utilitzant el métode drop. He eliminat del dataframe les columnes que no necessito per contestar l'exercici següent. 
    

print("\n\nDecideixo eliminar les columnes utilitzant el métode drop. He eliminat del dataframe les columnes que no necessito per contestar l'exercici següent.\n\n")
    
df3 = df2.drop(['Unnamed: 0','DayofMonth','DayOfWeek','CRSDepTime','CRSArrTime','UniqueCarrier','UniqueCarrier','TailNum','ActualElapsedTime', 'CRSElapsedTime','AirTime','TaxiIn','TaxiOut','Cancelled','CancellationCode','Diverted','CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay'], axis=1)
df3.info()
# Out:
# Les dades estan organitzades en 29 columnes, relatives als vols d'aeronaus. La primera columna(Unnamed:0) és un número correlatiu (al que li falten registres). La resta de columnes correspnoen a dades dels vols (dia del vol, hora de partida i d'arribada, lloc de sortida i destí, temps de retard, etc).
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936758 entries, 0 to 1936757
# Data columns (total 30 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Unnamed: 0         int64
#  1   Year               int64
#  2   Month              int64
#  3   DayofMonth         int64
#  4   DayOfWeek          int64
#  5   DepTime            float64
#  6   CRSDepTime         int64
#  7   ArrTime            float64
#  8   CRSArrTime         int64
#  9   UniqueCarrier      object
#  10  FlightNum          int64
#  11  TailNum            object
#  12  ActualElapsedTime  float64
#  13  CRSElapsedTime     float64
#  14  AirTime            float64
# ...

# %%
#- Exercici 2

#Fes un informe complet del dataset:

    #Resumeix estadísticament el dataset i les columnes d’interès. Fes una anàlisi estadístic del que consideris rellevant.

print("\n\nResumeix estadísticament el dataset i les columnes d’interès:\n")
print(df3.describe())
   
    #Troba quantes dades faltants hi ha per columna:

#print(df3.notnull()).
print("\n\nTroba quantes dades faltants hi ha per columna:\n")
print('Les dades faltants a ArrTime són: ',2000000- 1999282)
print('Les dades faltants a ArrDelay són: ',2000000- 199151, "\n\n")
 
    
    #Crea columnes noves (velocitat mitjana del vol, si ha arribat tard o no...).
#Columna VELOCITAT MITJANA

print("\n\nCrea columnes noves:\n\n")
df3["Velocitat_mijtana"]= (df3["ArrTime"] - df3["DepTime"]) / df3["Distance"]
print(df3)
    
    #Fes una taula de les aerolínies amb més endarreriments acumulats.
print("\nFes una taula de les aerolínies amb més endarreriments acumulats:\n No sé identificar, a l'arxiu original, quina columna identifica l'aerolinea\n")

    #Busca les rutes més llargues i les que acumulen més retards.
print("\nQuins són els vols més llargs?")

#print(df3["Distance"].max())
#print(df3["Distance"].idxmax())
#df3.loc(df3["Distance"] == df3["Distance"].max())

print(df3.loc[df3["Distance"] == df3["Distance"].max()])


print("\n i les que acumulen més retards:")
print(df3.loc[df3["ArrDelay"] == df3["ArrDelay"].max()])
# Out:
# Resumeix estadísticament el dataset i les columnes d’interès:
#
#            Year          Month        DepTime        ArrTime      FlightNum  \
# count  200000.0  200000.000000  200000.000000  199297.000000  200000.000000
# mean     2008.0       6.112810    1518.593590    1609.850133    2184.186385
# std         0.0       3.482167     449.844117     547.538877    1946.195793
# min      2008.0       1.000000       1.000000       1.000000       1.000000
# 25%      2008.0       3.000000    1203.000000    1317.000000     612.000000
# 50%      2008.0       6.000000    1545.000000    1715.000000    1540.000000
# 75%      2008.0       9.000000    1900.000000    2030.000000    3429.000000
# max      2008.0      12.000000    2400.000000    2400.000000    7829.000000
#
#             ArrDelay       DepDelay       Distance  Velocitat_mijtana
# count  199166.000000  200000.000000  200000.000000      199297.000000
# mean       42.079446      43.070830     764.059225           0.175637
# ...

# %%
#- Exercici 3

#Exporta el dataset net i amb les noves columnes a Excel.

df3.to_excel("Dades_vols.xlsx", encoding = "utf-8")
